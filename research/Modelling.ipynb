# %% [markdown]
# # Modelling Trails with Machine Learning Models

# %%
# IMport the required libraries
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# Import the required librarires
train = pd.read_csv("../Dataset/processed/train.csv")

train.head()
# Out:
#              TimeStamp  Holiday  Temperature  Rainfall_last_hour  \
# 0  2008-02-10 09:00:00      0.0       289.28                 0.0
# 1  2008-02-10 10:00:00      0.0       290.26                 0.0
# 2  2008-02-10 11:00:00      0.0       290.28                 0.0
# 3  2008-02-10 12:00:00      0.0       290.33                 0.0
# 4  2008-02-10 13:00:00      0.0       292.14                 0.0
#
#    Snowfall_last_hour  Cloud_Cover  Weather_Desc  Traffic_Vol  \
# 0                 0.0           40            19         5555
# 1                 0.0           75             9         4525
# 2                 0.0           90            10         4772
# 3                 0.0           90            10         5031
# 4                 0.0           75             9         4928
#
#    Weather_Airborne particles  Weather_Airborne smoke  Weather_Clear skies  \
# 0                       False                   False                False
# 1                       False                   False                False
# 2                       False                   False                False
# 3                       False                   False                False
# 4                       False                   False                False
#
#    Weather_Cloudy skies  Weather_Dense fog  Weather_Light fog  \
# 0                  True              False              False
# 1                  True              False              False
# 2                  True              False              False
# 3                  True              False              False
# 4                  True              False              False
#
#    Weather_Light rain  Weather_Rainfall  Weather_Snowfall  \
# 0               False             False             False
# 1               False             False             False
# 2               False             False             False
# 3               False             False             False
# 4               False             False             False
#
#    Weather_Stormy weather  Weather_Sudden windstorm
# 0                   False                     False
# 1                   False                     False
# 2                   False                     False
# 3                   False                     False
# 4                   False                     False

# %%
# Set the timestamp as the index
train = train.set_index("TimeStamp")

train.head()
# Out:
#                      Holiday  Temperature  Rainfall_last_hour  \
# TimeStamp
# 2008-02-10 09:00:00      0.0       289.28                 0.0
# 2008-02-10 10:00:00      0.0       290.26                 0.0
# 2008-02-10 11:00:00      0.0       290.28                 0.0
# 2008-02-10 12:00:00      0.0       290.33                 0.0
# 2008-02-10 13:00:00      0.0       292.14                 0.0
#
#                      Snowfall_last_hour  Cloud_Cover  Weather_Desc  \
# TimeStamp
# 2008-02-10 09:00:00                 0.0           40            19
# 2008-02-10 10:00:00                 0.0           75             9
# 2008-02-10 11:00:00                 0.0           90            10
# 2008-02-10 12:00:00                 0.0           90            10
# 2008-02-10 13:00:00                 0.0           75             9
#
#                      Traffic_Vol  Weather_Airborne particles  \
# TimeStamp
# 2008-02-10 09:00:00         5555                       False
# 2008-02-10 10:00:00         4525                       False
# 2008-02-10 11:00:00         4772                       False
# 2008-02-10 12:00:00         5031                       False
# 2008-02-10 13:00:00         4928                       False
#
#                      Weather_Airborne smoke  Weather_Clear skies  \
# TimeStamp
# 2008-02-10 09:00:00                   False                False
# 2008-02-10 10:00:00                   False                False
# 2008-02-10 11:00:00                   False                False
# 2008-02-10 12:00:00                   False                False
# 2008-02-10 13:00:00                   False                False
#
#                      Weather_Cloudy skies  Weather_Dense fog  \
# TimeStamp
# 2008-02-10 09:00:00                  True              False
# 2008-02-10 10:00:00                  True              False
# 2008-02-10 11:00:00                  True              False
# 2008-02-10 12:00:00                  True              False
# 2008-02-10 13:00:00                  True              False
#
#                      Weather_Light fog  Weather_Light rain  Weather_Rainfall  \
# TimeStamp
# 2008-02-10 09:00:00              False               False             False
# 2008-02-10 10:00:00              False               False             False
# 2008-02-10 11:00:00              False               False             False
# 2008-02-10 12:00:00              False               False             False
# 2008-02-10 13:00:00              False               False             False
#
#                      Weather_Snowfall  Weather_Stormy weather  \
# TimeStamp
# 2008-02-10 09:00:00             False                   False
# 2008-02-10 10:00:00             False                   False
# 2008-02-10 11:00:00             False                   False
# 2008-02-10 12:00:00             False                   False
# 2008-02-10 13:00:00             False                   False
#
#                      Weather_Sudden windstorm
# TimeStamp
# 2008-02-10 09:00:00                     False
# 2008-02-10 10:00:00                     False
# 2008-02-10 11:00:00                     False
# 2008-02-10 12:00:00                     False
# 2008-02-10 13:00:00                     False

# %% [markdown]
# ## Data Splitting

# %%
# Split the data into features and targets
features, target = train.drop("Traffic_Vol", axis=1), train["Traffic_Vol"]

features.shape, target.shape
# Out:
# ((38373, 17), (38373,))

# %%
# Split the training and testing sets
split_size = int(0.8 * (len(train)))

X_train, y_train = features[:split_size], target[:split_size]
X_val, y_val = features[split_size:], target[split_size:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((30698, 17), (30698,), (7675, 17), (7675,))

# %%
# Scale the dataset
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# ## Modelling

# %% [markdown]
# According to the hackathon, the Evaluation metric will be **Root Mean Square Error**

# %%
from sklearn.metrics import root_mean_squared_error

# %%
models = {
    "Linear" : LinearRegression(),
    "Ridge" : Ridge(),
    "Lasso": Lasso(),
    "Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42, n_jobs=-1)
}

# %%
for model in models.values():
    print(model)
# Out:
# LinearRegression()
# Ridge()
# Lasso()
# DecisionTreeRegressor(random_state=42)
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
def fit_and_score_model(models: dict, X_train=X_train, y_train= y_train, X_val=X_val, y_val=y_val):
    
    # Iterate through the models
    scores = {}
    
    for model_name, model in models.items():
        
        # Fit the model on the data
        model.fit(X_train, y_train)
        
        # Predict on test data
        y_preds = model.predict(X_val)
        
        # Score the predictions
        score = root_mean_squared_error(y_val, y_preds)
        
        scores[model_name] = round(score , 2)
    return scores
        
scores = fit_and_score_model(models)

# %%
# Convert the dictionary into a dataframe
scores_df = pd.DataFrame(scores.items(), columns=["Model Name", "Score"]).sort_values(by=["Score"])
scores_df
# Out:
#       Model Name    Score
# 2          Lasso  1959.27
# 0         Linear  1959.35
# 1          Ridge  1959.42
# 4  Random Forest  2195.25
# 3           Tree  2590.57
